# %% [markdown]
# <a href="https://colab.research.google.com/github/yyj1212-art/Python-for-Bioinformatics/blob/main/CHO_Cell_RNAseq_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. 데이터를 엑셀처럼 다루게 해주는 'pandas' 라이브러리 불러오기
import pandas as pd

# 2. 코랩에 업로드한 CHO 세포 데이터(압축파일)를 읽어서 'cho_counts'라는 변수에 저장하기
cho_counts = pd.read_csv("GSE294982_gene_counts.csv.gz")

# 3. 데이터가 잘 들어왔는지 표의 맨 위 5줄만 화면에 출력해보기
cho_counts.head()
# Out:
#    gene_id  B12_17_R1  B12_17_R2  B12_17_R3  B12_21_R1  B12_21_R2  B12_21_R3  \
# 0     A1cf     0.0000     0.0000     0.0000     1.0000     0.0000     0.0000
# 1  A3galt2     0.0000     0.0000     0.0000     0.0000     1.0000     1.0000
# 2   A4galt     1.0000     1.0000     2.0000     1.0000     5.0000     0.0000
# 3    A4gnt     0.0000     0.0000     0.0000     0.0000     0.0000     1.0000
# 4     Aaas  1542.9955  1444.9967  1332.9992  1521.9988  1589.0019  1493.9965
#
#      B12_R1    B12_R2     B12_R3  clone1-wt_R1  clone1-wt_R2  clone1-wt_R3  \
# 0    0.0000    0.0000    0.00000        0.0000        0.0000        0.0000
# 1    0.0000    0.0000    0.00000        0.0000        0.0000        0.0000
# 2    4.0000    2.0000    2.00000        0.0000        1.0000        0.0000
# 3    1.0000    0.0000    0.00000        0.0000        1.0000        0.0000
# 4  777.9996  850.9999  667.00039      749.9996      835.9996      799.0005
#
#    clone1_1_R1  clone1_1_R2  clone1_1_R3  clone1_3_R1  clone1_3_R2  \
# 0        0.000        0.000       0.0000       0.0000        0.000
# 1        1.000        0.000       0.0000       0.0000        0.000
# 2        0.000        0.000       1.0000       3.0000        1.000
# 3        0.000        0.000       0.0000       0.0000        0.000
# 4     1656.004     1364.995    1136.0034    1379.0025     1279.001
#
#    clone1_3_R3 Unnamed: 19
# 0       0.0000         NaN
# 1       0.0000         NaN
# 2       0.0000         NaN
# 3       0.0000         NaN
# 4    1875.9989         NaN

# %%
# 데이터의 전체 크기(행, 열 개수)와 데이터 타입을 한눈에 요약해서 보기
cho_counts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20076 entries, 0 to 20075
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   gene_id       20076 non-null  object
#  1   B12_17_R1     20076 non-null  float64
#  2   B12_17_R2     20076 non-null  float64
#  3   B12_17_R3     20076 non-null  float64
#  4   B12_21_R1     20076 non-null  float64
#  5   B12_21_R2     20076 non-null  float64
#  6   B12_21_R3     20076 non-null  float64
#  7   B12_R1        20076 non-null  float64
#  8   B12_R2        20076 non-null  float64
#  9   B12_R3        20076 non-null  float64
#  10  clone1-wt_R1  20076 non-null  float64
#  11  clone1-wt_R2  20076 non-null  float64
#  12  clone1-wt_R3  20076 non-null  float64
#  13  clone1_1_R1   20076 non-null  float64
#  14  clone1_1_R2   20076 non-null  float64
#  15  clone1_1_R3   20076 non-null  float64
#  16  clone1_3_R1   20076 non-null  float64
#  17  clone1_3_R2   20076 non-null  float64
#  18  clone1_3_R3   20076 non-null  float64
#  19  Unnamed: 19   48 non-null     object
# dtypes: float64(18), object(2)
# memory usage: 3.1+ MB

# %%
# 1. 19번 쓰레기 열('Unnamed: 19')을 데이터에서 완전히 삭제하기
# axis=1은 '열(세로줄)'을 지우겠다는 뜻입니다.
cho_clean = cho_counts.drop(columns=['Unnamed: 19'], axis=1)

# 2. 삭제 후 데이터가 잘 정제되었는지 다시 확인해보기
cho_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20076 entries, 0 to 20075
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   gene_id       20076 non-null  object
#  1   B12_17_R1     20076 non-null  float64
#  2   B12_17_R2     20076 non-null  float64
#  3   B12_17_R3     20076 non-null  float64
#  4   B12_21_R1     20076 non-null  float64
#  5   B12_21_R2     20076 non-null  float64
#  6   B12_21_R3     20076 non-null  float64
#  7   B12_R1        20076 non-null  float64
#  8   B12_R2        20076 non-null  float64
#  9   B12_R3        20076 non-null  float64
#  10  clone1-wt_R1  20076 non-null  float64
#  11  clone1-wt_R2  20076 non-null  float64
#  12  clone1-wt_R3  20076 non-null  float64
#  13  clone1_1_R1   20076 non-null  float64
#  14  clone1_1_R2   20076 non-null  float64
#  15  clone1_1_R3   20076 non-null  float64
#  16  clone1_3_R1   20076 non-null  float64
#  17  clone1_3_R2   20076 non-null  float64
#  18  clone1_3_R3   20076 non-null  float64
# dtypes: float64(18), object(1)
# memory usage: 2.9+ MB

# %%
# 1. gene_id 열을 제외하고, 모든 샘플(숫자 열)의 행별 합계 계산하기
# iloc[:, 1:]는 0번째 열(gene_id)을 제외한 모든 숫자 세로줄을 뜻합니다.
row_sums = cho_clean.iloc[:, 1:].sum(axis=1)

# 2. 모든 샘플의 발현량 합이 10 이상인 유전자만 골라내기 (노이즈 필터링)
cho_filtered = cho_clean[row_sums >= 10]

# 3. 필터링 후 몇 개의 유전자가 남았는지 행의 개수 확인하기
print("필터링 전 유전자 개수:", len(cho_clean))
print("필터링 후 유전자 개수:", len(cho_filtered))
# Out:
# 필터링 전 유전자 개수: 20076
# 필터링 후 유전자 개수: 13362
